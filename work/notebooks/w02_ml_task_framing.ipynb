# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/krashishkr008-ghg/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane as an ML Task
#
# **Lane:** Search Performance Optimization
#
# **ML Task Type:** Scoring (Regression)
#
# I chose the Search Performance Optimization lane. This is a scoring (regression) problem because the goal is to predict a numerical value, such as the click-through rate (CTR) or search performance score of a webpage. These predictions help identify which pages need improvement to increase search visibility.

# %%
# ML Task Type
task_type = "Scoring (Regression)"
print("Task Type:", task_type)
# Out:
# Task Type: Scoring (Regression)

# %% [markdown]
# ## Target or Proxy
#
# **Target:** Click-Through Rate (CTR)
#
# I would predict the Click-Through Rate (CTR) of a webpage. The target comes from an observed outcome because CTR is calculated from actual search data (clicks and impressions). If CTR is not available, average position can be used as a proxy to estimate search performance.

# %%
# Target variable
target = "CTR"
print("Target:", target)
# Out:
# Target: CTR

# %% [markdown]
# ## Success Metric
#
# **Success Metric:** Mean Absolute Error (MAE)
#
# I would use Mean Absolute Error (MAE) because the task is to predict a numerical value such as CTR. MAE measures the average difference between the predicted and actual values, which is easy to interpret. A lower MAE is better. For this project, an MAE below **1.0 percentage point of CTR** would be considered a good result because the predictions would be close to the real search performance.

# %%
# Success metric
metric = "Mean Absolute Error (MAE)"
print("Success Metric:", metric)
# Out:
# Success Metric: Mean Absolute Error (MAE)

# %% [markdown]
# ## The Unit of Analysis
#
# Each row in the dataframe represents one content page (webpage). The row contains information such as search volume, competition, CPC, content type, CTR, average position, engagement rate, and other search performance metrics for that page.

# %%
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A fixed rule cannot accurately predict search performance because many factors affect it at the same time, such as search volume, competition, content type, CTR, and average position. Machine learning can learn these complex patterns from data and provide better predictions than a simple if-statement.

# %%
# Reason why ML is preferred
reason = "ML can learn complex patterns from multiple features better than fixed rules."
print(reason)
# Out:
# ML can learn complex patterns from multiple features better than fixed rules.

# %% [markdown]
# ## Self-check
#
# - ✅ Every section above is filled with both markdown answers and supporting code where required.
# - ✅ The notebook runs from top to bottom without errors.
# - ✅ No client names, URLs, or private queries are included.
# - ✅ My claims use careful, evidence-based language such as observed, measured, directional, and decision-support.
# - ✅ The notebook is saved in my repository under `work/notebooks/` and is ready for submission.
